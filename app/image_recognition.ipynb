# %% [markdown]
# # Data Understanding

# %%
# package for data understanding
import matplotlib.pyplot as plt

from IPython.display import display

import pandas as pd

import numpy as np

from PIL import Image

import skimage.io

# %matplotlib inline

# %%
# 7ell image
img = Image.open('Pepper__bell___Bacterial_spot\\62ff339a-6883-4d8f-b7e3-913c1b950c38___JR_B.Spot 3347.JPG')

# tchouf image size
img_size = img.size

print("The image size is: {}".format(img_size))

img
# Out:
# The image size is: (256, 256)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x216A392E460>

# %%
# t7awel el image to array
img_data = np.array(img)

# image shape
img_data_shape = img_data.shape

print("the shape of our image shape: {}".format(img_data_shape))

red=img_data[:, :, 0]
green=img_data[:, :, 1]
blue=img_data[:, :, 1]

# plot the red channel
plt.imshow(red, cmap=plt.cm.Reds_r)
plt.show()

# plot the green channel
plt.imshow(green, cmap=plt.cm.Greens_r)
plt.show()

# plot the blue channel
plt.imshow(blue, cmap=plt.cm.Blues_r)
plt.show()
# Out:
# the shape of our image shape: (256, 256, 3)

# %%
def kde(channel, color):
    data = channel.flatten()
    return pd.Series(data).plot.density(c=color)

channels = ['r', 'g', 'b']
    
def plot_rgb(img):
    # ista5demana enumerate bech ndourou 3al indexes wel color
    for i, color in enumerate(channels):
        kde(img[:, :, i], color)
        
    plt.show()

plot_rgb(img_data)

# %%
# load 61fe0fde-0e1a-4977-adee-e9b66caaf809___NREC_B.Spot 1855.JPG
pepper = Image.open('Pepper__bell___Bacterial_spot\\61fe0fde-0e1a-4977-adee-e9b66caaf809___NREC_B.Spot 1855.JPG')

# display  image
display(pepper)

# NumPy array of the image data
pepper_data = np.array(pepper)

# plot the rgb densities 
plot_rgb(pepper_data)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x216A392EAF0>

# %%
# load 61fe0fde-0e1a-4977-adee-e9b66caaf809___NREC_B.Spot 1855.JPG
pepper2 = Image.open('Pepper__bell___Bacterial_spot\\64c23fb9-51a0-4690-bed5-47ab3af8c294___JR_B.Spot 9072.JPG')

# display  image
display(pepper2)

# NumPy array of the image data
pepper_data2 = np.array(pepper2)

# plot the rgb densities 
plot_rgb(pepper_data2)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x216D8B80B50>

# %%
# badeltha lonha gris mech colorful image
bp = pepper.convert("L")
display(pepper)

# convert the image to  array
pepper_b = np.array(bp)

pepper_b_shape = pepper_b.shape
print(" shape: {}".format(pepper_b_shape))

# plot the array using matplotlib
plt.imshow(pepper_b, cmap=plt.cm.gray)
plt.show()

# chouf function kde ba7dha plot_rgb
kde(pepper_b, 'k')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x216A392EAF0>
#  shape: (256, 256)
# <AxesSubplot:ylabel='Density'>

# %%
img=skimage.io.imread('Pepper__bell___Bacterial_spot/0169b9ac-07b9-4be1-8b85-da94481f05a4___NREC_B.Spot 9169.jpg')
flatten_img=img.ravel()
plt.hist(flatten_img,bins=255)
plt.show()

# %%
# Change the size of the image
import skimage.transform
from skimage.io import imsave

img_r=skimage.transform.resize(img,(64,64,3))
imsave("ya.jpg", img_r)
plt.imshow(img_r)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# # Data preparation

# %%
from glob import glob
import re
import os

# %%
#read all the folders in the list
folder=os.listdir('./')
folder=[i for i in folder if i!='PlantVillage']
print(folder)
# Out:
# ['.ipynb_checkpoints', '.~iiiii.ipynb', '.~image_recognition.ipynb', '.~wwwww.ipynb', 'data_small_size.csv', 'iiiii.ipynb', 'image_recognition.ipnyb', 'image_recognition.ipynb', 'image_recognition_2.ipynb', 'models', 'newImage.jpg', 'Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight', 'pretrained_model.h5', 'saved_images', 'saved_images.rar', 'saved_imgs', 'saved_imgs.rar', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_healthy', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_mosaic_virus', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'work.ipynb', 'wwwww.ipynb', 'yaya.jpg']

# %%
f1=[]
f2=[]
f3=[]
for i in folder:
    if "Pepper" in i:
        f1.append(i)
    elif "Potato" in i:
        f2.append(i)
    elif "Tomato" in i:
        f3.append(i)

# %%
print("Perpper folder{} \n Potato folder {} \n Tomato Folder {}".format(f1,f2,f3))
# Out:
# Perpper folder['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy']
#  Potato folder ['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']
#  Tomato Folder ['Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_healthy', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_mosaic_virus', 'Tomato__Tomato_YellowLeaf__Curl_Virus']

# %%
f=f1+f2+f3

# %%
all_path_p=[]
for i in f:
    all_path_p+=glob('{}/*.jpg'.format(i))

# %%
print(all_path_p[0])
# Out:
# Pepper__bell___Bacterial_spot\0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Spot 8964.JPG

# %%
data={"name":[],'class':[],'path':[]}
for p in all_path_p:
    num=p.index('\\')
    
    data['class'].append(str(p[:num]))
    data['name'].append(str(p[num+1:]))
    data['path'].append(str(p))

# %%
import pandas as pd
df_p= pd.DataFrame.from_dict(data)

# %%
df_p.head()
# Out:
#                                                 name  \
# 0  0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Sp...
# 1  006adb74-934f-448f-a14f-62181742127b___JR_B.Sp...
# 2  00f2e69a-1e56-412d-8a79-fdce794a17e4___JR_B.Sp...
# 3  01613cd0-d3cd-4e96-945c-a312002037bf___JR_B.Sp...
# 4  0169b9ac-07b9-4be1-8b85-da94481f05a4___NREC_B....
#
#                            class  \
# 0  Pepper__bell___Bacterial_spot
# 1  Pepper__bell___Bacterial_spot
# 2  Pepper__bell___Bacterial_spot
# 3  Pepper__bell___Bacterial_spot
# 4  Pepper__bell___Bacterial_spot
#
#                                                 path
# 0  Pepper__bell___Bacterial_spot\0022d6b7-d47c-4e...
# 1  Pepper__bell___Bacterial_spot\006adb74-934f-44...
# 2  Pepper__bell___Bacterial_spot\00f2e69a-1e56-41...
# 3  Pepper__bell___Bacterial_spot\01613cd0-d3cd-4e...
# 4  Pepper__bell___Bacterial_spot\0169b9ac-07b9-4b...

# %%
# import skimage.transform
# from skimage.io import imsave


# def process_image(path,name):
#     img=skimage.io.imread(path)
#     img_r=skimage.transform.resize(img,(64,64,3))
#     imsave("saved_imgs\{}.jpg".format(path), img_r)


# # for loop over image paths
# for img_path,name in zip(all_path_p,df_p['class']):
#     process_image(img_path,type)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23368/735862131.py in <module>
#      11 # for loop over image paths
#      12 for img_path,name in zip(all_path_p,df_p['class']):
# ---> 13     process_image(img_path,type)
#
# ~\AppData\Local\Temp/ipykernel_23368/735862131.py in process_image(path, name)
#       6     img=skimage.io.imread(path)
#       7     img_r=skimage.transform.resize(img,(64,64,3))
# ----> 8     imsave("saved_imgs\{}.jpg".format(path), img_r)
#       9
#      10
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\skimage\io\_io.py in imsave(fname, arr, plugin, check_contrast, **plugin_args)
#     141     if check_contrast and is_low_contrast(arr):
#     142         warn('%s is a low contrast image' % fname)
# --> 143     return call_plugin('imsave', fname, arr, plugin=plugin, **plugin_args)
#     144
#     145
#
# ...

# %%
folder=os.listdir('./saved_imgs/')
folder=[i for i in folder if i!='PlantVillage']
print(folder)
# Out:
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_healthy', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_mosaic_virus', 'Tomato__Tomato_YellowLeaf__Curl_Virus']

# %%
f1=[]
f2=[]
f3=[]
for i in folder:
    if "Pepper" in i:
        f1.append(i)
    elif "Potato" in i:
        f2.append(i)
    elif "Tomato" in i:
        f3.append(i)

# %%
f=f1+f2+f3

# %%
all_path=[]
for i in f:
    all_path+=glob('saved_imgs\{}/*.jpg'.format(i))

# %%
print(len(all_path_p))
print(len(all_path))

# %%
print(all_path[0])

# %%
data={"name":[],'class':[],'path':[]}
for a in all_path:
    i1=a.index('\\')
    p=a[i1+1:]
    num=p.index('\\')
    data['class'].append(str(p[:num]))
    data['name'].append(str(p[num+1:]))
    data['path'].append(str(a))

# %%
import pandas as pd
df= pd.DataFrame.from_dict(data)

# %%
df.head()

# %%
(df['class']).value_counts()

# %%
df.to_csv('data_small_size.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24072/2391162235.py in <module>
# ----> 1 df.to_csv('data_small_size.csv')
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Modeling and Machine Learning

# %%
import matplotlib.pyplot as plt

from IPython.display import display

import pandas as pd

import numpy as np

from PIL import Image

import skimage.io

# %matplotlib inline

# %%
df = pd.read_csv("data_small_size.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Sp...
# 1           1  006adb74-934f-448f-a14f-62181742127b___JR_B.Sp...
# 2           2  00f2e69a-1e56-412d-8a79-fdce794a17e4___JR_B.Sp...
# 3           3  01613cd0-d3cd-4e96-945c-a312002037bf___JR_B.Sp...
# 4           4  0169b9ac-07b9-4be1-8b85-da94481f05a4___NREC_B....
#
#                            class  \
# 0  Pepper__bell___Bacterial_spot
# 1  Pepper__bell___Bacterial_spot
# 2  Pepper__bell___Bacterial_spot
# 3  Pepper__bell___Bacterial_spot
# 4  Pepper__bell___Bacterial_spot
#
#                                                 path
# 0  saved_imgs\Pepper__bell___Bacterial_spot\0022d...
# 1  saved_imgs\Pepper__bell___Bacterial_spot\006ad...
# 2  saved_imgs\Pepper__bell___Bacterial_spot\00f2e...
# 3  saved_imgs\Pepper__bell___Bacterial_spot\01613...
# 4  saved_imgs\Pepper__bell___Bacterial_spot\0169b...

# %%
from skimage.feature import hog
from skimage.color import rgb2gray
import os

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# bech n9assmou data mabin test w train
from sklearn.model_selection import train_test_split

# SVM MACHINE LEARNING Model
from sklearn.svm import SVC

# SGD MACHINE LEARNING Model
from sklearn.linear_model import SGDClassifier

# GridSearch
from sklearn.model_selection import GridSearchCV

import sklearn.metrics

# import accuracy_score from sklearn's metrics module
from sklearn.metrics import roc_curve, auc, accuracy_score

# %%
# load the labels using pandas
import os
df = pd.read_csv("data_small_size.csv")

# show the first five rows of the dataframe using head
display(df.head())

def get_image(name,df): 
    for i,j in zip(df.name,df.path):
        if name==i:
            filename = "{}".format(j)
            file_path = os.path.join(filename)
            img = Image.open(file_path)
           
            

            return np.array(img)

# subset the dataframe to just Apis (genus is 0.0) get the value of the sixth item in the index
name=df.name[0]
plt.imshow(get_image(name,df))
plt.show()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Sp...
# 1           1  006adb74-934f-448f-a14f-62181742127b___JR_B.Sp...
# 2           2  00f2e69a-1e56-412d-8a79-fdce794a17e4___JR_B.Sp...
# 3           3  01613cd0-d3cd-4e96-945c-a312002037bf___JR_B.Sp...
# 4           4  0169b9ac-07b9-4be1-8b85-da94481f05a4___NREC_B....
#
#                            class  \
# 0  Pepper__bell___Bacterial_spot
# 1  Pepper__bell___Bacterial_spot
# 2  Pepper__bell___Bacterial_spot
# 3  Pepper__bell___Bacterial_spot
# 4  Pepper__bell___Bacterial_spot
#
#                                                 path
# 0  saved_imgs\Pepper__bell___Bacterial_spot\0022d...
# 1  saved_imgs\Pepper__bell___Bacterial_spot\006ad...
# 2  saved_imgs\Pepper__bell___Bacterial_spot\00f2e...
# 3  saved_imgs\Pepper__bell___Bacterial_spot\01613...
# 4  saved_imgs\Pepper__bell___Bacterial_spot\0169b...

# %%
# Image manipulation with rgb2gray


pepper_image = get_image(name,df)

# print the shape of the bombus image
print('pepper image has shape: ', pepper_image.shape)

# convert image to grayscale
gray_pepper_image = rgb2gray(pepper_image)

# show the grayscale image
plt.imshow(gray_pepper_image, cmap=plt.cm.gray)

# confirm grayscale image 
print('Grayscale  image has shape: ', gray_pepper_image.shape)
# Out:
# pepper image has shape:  (64, 64, 3)
# Grayscale  image has shape:  (64, 64)

# %%
# Exemple of hog transformation
from skimage import morphology


hog_features, hog_image = hog(gray_pepper_image,
                              visualize=True,
                              block_norm='L2-Hys',
                              pixels_per_cell=(2, 2))

# show our hog_image with a gray color 
plt.imshow(hog_image, cmap=plt.cm.gray)

# %%
print(pepper_image.shape)
# Out:
# (64, 64, 3)

# %%
# Exemple of feature array 
def create_features(img):
    # flatten img
    color_features = img.flatten()
    # convert image to grayscale
    gray_image = rgb2gray(img)
    # get HOG features
    hog_features = hog(gray_image, block_norm='L2-Hys', pixels_per_cell=(16, 16))
    # combine color and hog features 
    flat_features = np.hstack([color_features, hog_features])
    return flat_features

pepper_features = create_features(pepper_image)

# print shape of bombus_features
pepper_features
# Out:
# array([1.23000000e+02, 1.08000000e+02, 1.11000000e+02, ...,
#        7.75082329e-03, 8.54132824e-03, 4.93170867e-03])

# %%
len(df)
# Out:
# 20636

# %%
# Create feature matrix

def create_feature_matrix(dataframe):
    features_list = []
    
    for name in dataframe.name:
        img = get_image(name,dataframe)
        image_features = create_features(img)
        features_list.append(image_features)
        
    feature_matrix = np.array(features_list)
    return feature_matrix

# run create_feature_matrix on our dataframe of image
feature_matrix = create_feature_matrix(df)
feature_matrix
# Out:
# array([[1.23000000e+02, 1.08000000e+02, 1.11000000e+02, ...,
#         7.75082329e-03, 8.54132824e-03, 4.93170867e-03],
#        [1.43000000e+02, 1.28000000e+02, 1.49000000e+02, ...,
#         3.72209375e-02, 2.00217317e-02, 2.55710270e-02],
#        [9.90000000e+01, 9.60000000e+01, 1.07000000e+02, ...,
#         3.11165736e-02, 2.67692740e-02, 4.03969172e-02],
#        ...,
#        [1.48000000e+02, 1.37000000e+02, 1.41000000e+02, ...,
#         6.69054453e-02, 5.08595157e-02, 5.22539816e-02],
#        [1.35000000e+02, 1.35000000e+02, 1.35000000e+02, ...,
#         2.00696607e-02, 1.81725717e-02, 1.33063272e-02],
#        [7.60000000e+01, 7.60000000e+01, 7.60000000e+01, ...,
#         1.64434854e-02, 3.73411083e-02, 2.21070989e-02]])

# %%
# n9assmou test and train
X_train, X_test, y_train, y_test = train_test_split(feature_matrix,
                                                    df['class'],
                                                    test_size=.3,
                                                    random_state=1234123)

# %%
pd.Series(y_train).value_counts()
# Out:
# Tomato__Tomato_YellowLeaf__Curl_Virus          2282
# Tomato_Bacterial_spot                          1501
# Tomato_Late_blight                             1341
# Tomato_Septoria_leaf_spot                      1194
# Tomato_Spider_mites_Two_spotted_spider_mite    1157
# Tomato_healthy                                 1072
# Pepper__bell___healthy                         1046
# Tomato__Target_Spot                            1015
# Pepper__bell___Bacterial_spot                   722
# Potato___Early_blight                           710
# Potato___Late_blight                            706
# Tomato_Early_blight                             683
# Tomato_Leaf_Mold                                647
# Tomato__Tomato_mosaic_virus                     265
# Potato___healthy                                104
# Name: class, dtype: int64

# %%
pd.Series(y_test).value_counts()
# Out:
# Tomato__Tomato_YellowLeaf__Curl_Virus          926
# Tomato_Bacterial_spot                          626
# Tomato_Septoria_leaf_spot                      577
# Tomato_Late_blight                             567
# Tomato_healthy                                 519
# Tomato_Spider_mites_Two_spotted_spider_mite    519
# Pepper__bell___healthy                         431
# Tomato__Target_Spot                            389
# Tomato_Early_blight                            317
# Tomato_Leaf_Mold                               305
# Potato___Late_blight                           294
# Potato___Early_blight                          290
# Pepper__bell___Bacterial_spot                  275
# Tomato__Tomato_mosaic_virus                    108
# Potato___healthy                                48
# Name: class, dtype: int64

# %%
# get shape of our training features
print('Training features matrix shape', X_train.shape)

# standard scaler
ss = StandardScaler()

# fit the scaler and transform the training features
train_stand = ss.fit_transform(X_train)

# use fit_transform to run PCA on our standardized training features
test_stand = ss.transform(X_test)

# look at the new shape of the standardized feature matrices
print('Standardized training features matrix shape is: ', train_stand.shape)
print('Standardized test features matrix shape is: ', test_stand.shape)
# Out:
# Training features matrix shape (14445, 12612)
# Standardized training features matrix shape is:  (14445, 12612)
# Standardized test features matrix shape is:  (6191, 12612)

# %%
import pickle
pickle.dump(ss, open(r'C:\Users\USERTEST\Desktop\Mosh\Freelance projects\project\PlantVillage\models\scaler.pickle', 'wb'))

# %%
#Performing PCA

# Instantiate a PCA object with 340 components
pca = PCA(n_components=350)

# use fit_transform on our standardized training features
X_train = pca.fit_transform(train_stand)

# use transform on our standardized test features
X_test = pca.transform(test_stand)

# look at the new shape of the transformed matrices
print('Training features matrix is: ', X_train.shape)
print('Test features matrix is: ', X_test.shape)
# Out:
# Training features matrix is:  (14445, 350)
# Test features matrix is:  (6191, 350)

# %%
import pickle
pickle.dump(pca, open(r'C:\Users\USERTEST\Desktop\Mosh\Freelance projects\project\PlantVillage\models\pca.pickle', 'wb'))

# %% [markdown]
# ### SVM

# %%
from sklearn.model_selection import GridSearchCV
 
# defining parameter range
param_grid = {'C': [0.1, 1],
              'gamma': [1, 0.1],
              'kernel': ['rbf','poly','sigmoid']}
 
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
 
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.158 total time=  56.7s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.158 total time= 1.0min
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.158 total time= 1.0min
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.158 total time=  58.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.158 total time= 1.1min
# [CV 1/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.759 total time=  21.4s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.748 total time=  20.2s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.775 total time=  18.9s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.778 total time=  18.3s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.758 total time=  17.8s
# [CV 1/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.175 total time=  20.3s
# ...

# %%
model_best=grid.best_estimator_

# %%
model_best.get_params()
# Out:
# {'C': 0.1,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 1,
#  'kernel': 'poly',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
from sklearn.metrics import classification_report, confusion_matrix
cr=classification_report(y_test, y_pred,output_dict=True)
pd.DataFrame(cr).T
# Out:
#                                              precision    recall  f1-score  \
# Pepper__bell___Bacterial_spot                 0.699531  0.541818  0.610656
# Pepper__bell___healthy                        0.832184  0.839907  0.836028
# Potato___Early_blight                         0.771930  0.910345  0.835443
# Potato___Late_blight                          0.538283  0.789116  0.640000
# Potato___healthy                              0.656250  0.437500  0.525000
# Tomato_Bacterial_spot                         0.714970  0.953674  0.817248
# Tomato_Early_blight                           0.649425  0.356467  0.460285
# Tomato_Late_blight                            0.828571  0.562610  0.670168
# Tomato_Leaf_Mold                              0.772242  0.711475  0.740614
# Tomato_Septoria_leaf_spot                     0.770492  0.733102  0.751332
# Tomato_Spider_mites_Two_spotted_spider_mite   0.806026  0.824663  0.815238
# ...

# %%
import pickle
pickle.dump(model_best, open(r'C:\Users\USERTEST\Desktop\Mosh\Freelance projects\project\PlantVillage\models\SVM.pickle', 'wb'))

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_best,X_train, y_train, cv=5)
scores
# Out:
# array([0.75908619, 0.74766355, 0.77466251, 0.77812392, 0.75839391])

# %%
y_pred_svm = grid.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Model accuracy is: ', accuracy)
# Out:
# Model accuracy is:  0.7758035858504281

# %%
pd.Series(y_pred_svm).value_counts()
# Out:
# Tomato__Tomato_YellowLeaf__Curl_Virus          902
# Tomato_Bacterial_spot                          835
# Tomato_healthy                                 556
# Tomato_Septoria_leaf_spot                      549
# Tomato_Spider_mites_Two_spotted_spider_mite    531
# Pepper__bell___healthy                         435
# Potato___Late_blight                           431
# Tomato__Target_Spot                            405
# Tomato_Late_blight                             385
# Potato___Early_blight                          342
# Tomato_Leaf_Mold                               281
# Pepper__bell___Bacterial_spot                  213
# Tomato_Early_blight                            174
# Tomato__Tomato_mosaic_virus                    120
# Potato___healthy                                32
# dtype: int64

# %%
# define support vector classifier
svm_rbf = SVC(kernel='rbf', probability=True, random_state=42)

# fit model
svm_rbf.fit(X_train, y_train)

# generate predictions
y_pred_rbf = svm_rbf.predict(X_test)
print(len(y_pred))

# calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print('Model accuracy is: ', accuracy)
# Out:
# 6191
# Model accuracy is:  0.8270069455661444

# %%
import pickle
pickle.dump(svm_rbf, open(r'C:\Users\USERTEST\Desktop\Mosh\Freelance projects\project\PlantVillage\models\svm_rbf.pickle', 'wb'))

# %%
cr=sklearn.metrics.classification_report(y_test,y_pred_rbf,output_dict=True)
pd.DataFrame(cr).T
# Out:
#                                              precision    recall  f1-score  \
# Pepper__bell___Bacterial_spot                 0.767296  0.443636  0.562212
# Pepper__bell___healthy                        0.816901  0.807425  0.812135
# Potato___Early_blight                         0.800623  0.886207  0.841244
# Potato___Late_blight                          0.550173  0.540816  0.545455
# Potato___healthy                              0.666667  0.041667  0.078431
# Tomato_Bacterial_spot                         0.543478  0.878594  0.671551
# Tomato_Early_blight                           0.670000  0.211356  0.321343
# Tomato_Late_blight                            0.831025  0.529101  0.646552
# Tomato_Leaf_Mold                              0.787500  0.619672  0.693578
# Tomato_Septoria_leaf_spot                     0.626728  0.707106  0.664495
# Tomato_Spider_mites_Two_spotted_spider_mite   0.767318  0.832370  0.798521
# ...

# %% [markdown]
# #### How to choose the best SVM kernel for your dataset
# ###### I am well aware of the fact that you must be having this question how to decide which kernel function will work efficiently for your dataset.
#
# ###### It totally depends on what problem you’re actually solving. If your data is linearly separable, without a second thought, go for a linear kernel.
#
# ###### Because a linear kernel takes less training time when compared to other kernel functions.
#
# ###### The linear kernel is mostly preferred for text classification problems as it performs well for large datasets.
# ###### Gaussian kernels tend to give good results when there is no additional information regarding data that is not available.
# ###### Rbf kernel is also a kind of Gaussian kernel which projects the high dimensional data and then searches a linear separation for it.
# ###### Polynomial kernels give good results for problems where all the training data is normalized.

# %% [markdown]
# ### SGD

# %%
model_sgd=SGDClassifier(loss='hinge',learning_rate='adaptive',early_stopping=True,eta0=0.1)
model_sgd.fit(X_train,y_train)
y_pred_test=model_sgd.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print('Model accuracy is: ', accuracy)
# Out:
# Model accuracy is:  0.8270069455661444

# %%
import pickle
pickle.dump(model_sgd, open(r'C:\Users\USERTEST\Desktop\Mosh\Freelance projects\project\PlantVillage\models\sgd.pickle', 'wb'))

# %%
cr=sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)
pd.DataFrame(cr).T
# Out:
#                                              precision    recall  f1-score  \
# Pepper__bell___Bacterial_spot                 0.614786  0.574545  0.593985
# Pepper__bell___healthy                        0.825893  0.858469  0.841866
# Potato___Early_blight                         0.781437  0.900000  0.836538
# Potato___Late_blight                          0.623457  0.687075  0.653722
# Potato___healthy                              0.215686  0.229167  0.222222
# Tomato_Bacterial_spot                         0.794671  0.809904  0.802215
# Tomato_Early_blight                           0.483607  0.372240  0.420677
# Tomato_Late_blight                            0.667946  0.613757  0.639706
# Tomato_Leaf_Mold                              0.682594  0.655738  0.668896
# Tomato_Septoria_leaf_spot                     0.703901  0.688042  0.695881
# Tomato_Spider_mites_Two_spotted_spider_mite   0.746789  0.784200  0.765038
# ...

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR
# Out:
# LogisticRegression(C=0.01, solver='liblinear')

# %%
import pickle
pickle.dump(LR, open(r'C:\Users\USERTEST\Desktop\Mosh\Freelance projects\project\PlantVillage\models\LR.pickle', 'wb'))

# %%
yhat = LR.predict(X_test)
accuracy = accuracy_score(y_test, yhat)
print('Model accuracy is: ', accuracy)
# Out:
# Model accuracy is:  0.7342917137780649

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print('Model accuracy is: ', accuracy)
# Out:
# Model accuracy is:  0.42303343563236956

# %%
import pickle
pickle.dump(gnb, open(r'C:\Users\USERTEST\Desktop\Mosh\Freelance projects\project\PlantVillage\models\gnb.pickle', 'wb'))

# %% [markdown]
# ### Deep Learning

# %% [markdown]
# ### convolutional neural networks

# %%
import pickle
from pathlib import Path
from skimage import io

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# import keras library
import keras

# import Sequential from the keras models module
from keras.models import Sequential

from tensorflow.keras import layers,regularizers

from tensorflow.keras.layers import Dense, Flatten, Conv2D, BatchNormalization, MaxPool2D, Dropout



# import Dense, Dropout, Flatten, Conv2D, MaxPooling2D from the keras layers module
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
import tensorflow as tf

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "saved_imgs",
    seed=123,
    shuffle=True,
    image_size=(64,64),
    batch_size=300
)
# Out:
# Found 20636 files belonging to 15 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Pepper__bell___Bacterial_spot',
#  'Pepper__bell___healthy',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'Tomato_Bacterial_spot',
#  'Tomato_Early_blight',
#  'Tomato_Late_blight',
#  'Tomato_Leaf_Mold',
#  'Tomato_Septoria_leaf_spot',
#  'Tomato_Spider_mites_Two_spotted_spider_mite',
#  'Tomato__Target_Spot',
#  'Tomato__Tomato_YellowLeaf__Curl_Virus',
#  'Tomato__Tomato_mosaic_virus',
#  'Tomato_healthy']

# %%
len(dataset)

# %%
def train_test_split_tf(ds, train_split=0.7, validation_split=0.2, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + validation_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    validation_size = int(validation_split * ds_size)
    
    train_ds = ds.take(train_size)    
    validation_ds = ds.skip(train_size).take(validation_size)
    test_ds = ds.skip(train_size).skip(validation_size)
    
    return train_ds, validation_ds, test_ds

# %%
train_ds, validation_ds, test_ds = train_test_split_tf(dataset)

# %%
test_ds
# Out:
# <SkipDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
validation_ds = validation_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
train_ds.take(1)
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# set model constants
num_classes = 15

# define model as Sequential
model = Sequential()

# first convolutional layer with 32 filters
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(64, 64, 3)))

# add a second 2D convolutional layer with 64 filters
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))

# reduce dimensionality through max pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

# third convolutional layer with 64 filters
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# add dropout to prevent over fitting
model.add(Dropout(0.25))
# necessary flatten step preceeding dense layer
model.add(Flatten())
# fully connected layer
model.add(Dense(128, activation='relu'))

# add additional dropout to prevent overfitting
model.add(Dropout(0.5))

# prediction layers
model.add(Dense(num_classes, activation='softmax', name='preds'))

# show model summary
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_21 (Conv2D)          (None, 62, 62, 32)        896
#
#  conv2d_22 (Conv2D)          (None, 60, 60, 64)        18496
#
#  max_pooling2d_12 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 28, 28, 64)        36928
#
#  dropout_12 (Dropout)        (None, 28, 28, 64)        0
#
#  flatten_6 (Flatten)         (None, 50176)             0
#
#  dense_10 (Dense)            (None, 128)               6422656
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  preds (Dense)               (None, 15)                1935
#
# ...
# Total params: 6,480,911
# Trainable params: 6,480,911
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers


model.compile(
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    # set the optimizer as stochastic gradient descent
    optimizer=optimizers.SGD(lr=0.001),
    # set the metric as accuracy
    metrics=['accuracy']
)

# mock-train the model using the first ten observations of the train and test sets
history=model.fit(
    train_ds,
    batch_size=300,
    validation_data=validation_ds,
    verbose=1,
    epochs=50
    
)
# Out:
# Epoch 1/50
# 48/48 [==============================] - 72s 1s/step - loss: 2.4929 - accuracy: 0.1851 - val_loss: 2.3021 - val_accuracy: 0.2769
# Epoch 2/50
# 48/48 [==============================] - 73s 2s/step - loss: 2.3686 - accuracy: 0.2387 - val_loss: 2.1325 - val_accuracy: 0.3418
# Epoch 3/50
# 48/48 [==============================] - 74s 2s/step - loss: 2.2765 - accuracy: 0.2783 - val_loss: 2.0497 - val_accuracy: 0.3823
# Epoch 4/50
# 48/48 [==============================] - 74s 2s/step - loss: 2.2117 - accuracy: 0.2998 - val_loss: 2.0608 - val_accuracy: 0.3474
# Epoch 5/50
# 48/48 [==============================] - 74s 2s/step - loss: 2.1432 - accuracy: 0.3297 - val_loss: 1.9802 - val_accuracy: 0.4003
# Epoch 6/50
# 48/48 [==============================] - 75s 2s/step - loss: 2.0949 - accuracy: 0.3401 - val_loss: 1.8604 - val_accuracy: 0.4631
# Epoch 7/50
# ...

# %%
scores = model.evaluate(test_ds)
print("the scores are {}".format(scores))

# %%
EPOCHS=10

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save('pretrained_model.h5')

# %%
# load pre-trained model
train_ds, validation_ds, test_ds
pretrained_cnn = keras.models.load_model('pretrained_model.h5')

# evaluate model on test set

score = pretrained_cnn.evaluate(test_ds, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

print("")

# evaluate model on holdout set
eval_score = pretrained_cnn.evaluate(validation_ds, verbose=0)
# print loss score
print('Eval loss:', eval_score[0])
# print accuracy score
print('Eval accuracy:', eval_score[1])
